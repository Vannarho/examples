# %% [markdown]
# # Example 1 hello: installed wheel import
#
# This notebook executes against the installed `vannarho-risk-engine` wheel only.

# %%
from pathlib import Path
import importlib.metadata as metadata
import VRE

module_path = Path(VRE.__file__).resolve()
print("vannarho-risk-engine", metadata.version("vannarho-risk-engine"))
print("VRE module", module_path)
assert any(part in {"site-packages", "dist-packages"} for part in module_path.parts)
assert "build" not in module_path.parts
